# %% [markdown]
# # League of Conservation Voters (LCV) Analysis
# ## Visualizations + Statistical Tests
#
# For details on data processing, please refer to the processing code for [<u>LCV</u>](https://github.com/cassiebuhler/datasets/tree/main/lcv).
#
# In this script, we are visualizing the resulting LCV data and running statistical tests.

# %%
import os
import geopandas as gpd
import ibis
from ibis import _
from cng.utils import *
from cng.h3 import *
import ibis.expr.datatypes as dt  
import re
from minio import Minio
import altair as alt
from utils import * 

duckdb_install_h3()
con = ibis.duckdb.connect(extensions = ["spatial", "h3"])
set_secrets(con)

bucket = "public-election"
s3_prefix = "league_of_conservation_voters/congressional_votes"

# %% [markdown]
# ## Distribution of LCV categories across votes

# %%
lcv_url = f's3://{bucket}/{s3_prefix}/**.csv'
lcv_votes = con.read_csv(lcv_url).distinct()

cat_url=f's3://{bucket}/{s3_prefix}/categories/lcv_vote_categories.csv'
cats = con.read_csv(cat_url) #categories of each vote
lcv= lcv_votes.left_join(cats,'id').drop('id_right') #joining categories to votes 
print((lcv.group_by('category').agg(n=_.count()).execute()))

multi_cat_votes = lcv.group_by('id').agg(num_categories=_.count()).filter(_.num_categories>1)
print(f'There are {multi_cat_votes.count().execute()} votes that span multiple categories')
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#        category    n
# 0   agriculture    5
# 1      wildlife  228
# 2   clean_water  238
# 3  public_lands  405
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# There are 216 votes that span multiple categories

# %% [markdown]
# ### Saving data

# %%
cats = con.read_csv(cat_url).group_by('id').agg(categories=_.category.collect())
lcv= lcv_votes.left_join(cats,'id').drop('id_right') #joining categories to votes 
lcv.to_csv('lcv_congressional_votes_filtered.csv')

# %% [markdown]
# # Classifying vote mechanism

# %%
import pandas as pd
from pathlib import Path
from classify_lcv_votes import scrape_all, classify_all

df = pd.read_csv('lcv_congressional_votes_filtered.csv')
df = scrape_all(df, Path('lcv_descriptions_cache.csv'))
df = classify_all(df)
df.to_csv('lcv_congressional_votes_mechanism.csv')
df['mechanism_category'].value_counts()
# Out:
# Loaded 625 cached descriptions from lcv_descriptions_cache.csv
# mechanism_category
# regulation_standards           333
# land_designation_management    141
# funding_appropriations         119
# other                           32
# Name: count, dtype: int64

# %% [markdown]
# # LCV statistical tests
#
# computing pro-conservation vote rate among each party and year

# %%
url = f's3://{bucket}/{s3_prefix}/roll_call_votes/**.csv'
lcv_df = con.read_csv(url)

#computed the annual pro-conservation vote rate among each congressperson
member_year = (lcv_df
    .filter(~_.vote_type.isin(['missing','unknown','excused']))
    .mutate(district_str=_.district.cast("string"))
    .mutate(district_str=_.district_str.fillna("STATEWIDE"))
    .mutate(member_id=_.first_name+'-'+_.last_name+'-'+_.state+'-'+_.chamber+'-'+_.district_str)
    .filter(_.vote_type.isin(['pro','anti','missing']))
    .group_by('year','party','chamber','member_id')
    .agg(total_votes=_.count(),
         total_pro_votes=(_.vote_type=='pro').sum())
    .mutate(pro_rate=_.total_pro_votes/_.total_votes)
    .mutate(party=_.party.substitute({'I':"Independent","R":"Republican","D":"Democrat"}))
    .order_by("total_votes") 
     )

# aggregating by party and year  
party_year = (
    member_year
    .group_by("year", "party")
    .agg(
        med_pro_rate=_.pro_rate.median(),
        n_members=_.member_id.nunique(),
        n_member_years=_.pro_rate.count(),
    )
    .order_by("year")
)


chart_cons_time = year_line_lcv(
    party_year,
    y="med_pro_rate",
    group="party",
    title=["Median Pro-Conservation Vote Rate by Party" ],
    y_title=["Pro-Conservation","Vote Rate (Median)"],
    stat="percent",
)

chart_cons_time.save('lcv_party.png', ppi=300)

chart_cons_time
# Out:
# /opt/venv/lib/python3.12/site-packages/ibis/common/deferred.py:414: FutureWarning: `Value.fillna` is deprecated as of v9.1; use fill_null instead
#   return func(*args, **kwargs)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# alt.Chart(...)

# %% [markdown]
# # Binomial Panel Regression of Pro-Conservation Voting by Party

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import pandas as pd

df = member_year.execute().copy()

df = df.dropna(subset=["total_votes", "total_pro_votes", "party", "year", "chamber", "member_id"])
df = df[df["total_votes"] > 0].copy()

df["pro_rate"] = df["total_pro_votes"] / df["total_votes"]

df["party_clean"] = df["party"].astype(str).str.strip().str.upper().replace(
    {"D":"DEMOCRAT", "R":"REPUBLICAN", "I":"INDEPENDENT"}
)
df = df[df["party_clean"].isin(["DEMOCRAT","REPUBLICAN","INDEPENDENT"])].copy()
df["party_clean"] = pd.Categorical(df["party_clean"], categories=["DEMOCRAT","REPUBLICAN","INDEPENDENT"])

# Grouped-binomial GLM (fractional logit)
m = smf.glm(
    "pro_rate ~ C(party_clean) + C(year) + C(chamber)",
    data=df,
    family=sm.families.Binomial(),
    freq_weights=df["total_votes"],   
).fit(
    cov_type="cluster",
    cov_kwds={"groups": df["member_id"]}
)

print(m.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:               pro_rate   No. Observations:                20550
# Model:                            GLM   Df Residuals:                   194772
# Model Family:                Binomial   Df Model:                           41
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -55884.
# Date:                Wed, 10 Jun 2026   Deviance:                       56758.
# Time:                        23:29:33   Pearson chi2:                 7.19e+04
# No. Iterations:                     6   Pseudo R-squ. (CS):             0.9985
# Covariance Type:              cluster
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                         0.6924      0.190      3.645      0.000       0.320       1.065
# C(party_clean)[T.REPUBLICAN]     -4.1660      0.081    -51.676      0.000      -4.324      -4.008
# C(party_clean)[T.INDEPENDENT]    -0.3128      0.406     -0.770      0.441      -1.109       0.484
# C(year)[T.1989]                   1.8854      0.186     10.114      0.000       1.520       2.251
# C(year)[T.1990]                   2.3070      0.187     12.305      0.000       1.940       2.675
# C(year)[T.1991]                   1.8319      0.200      9.175      0.000       1.441       2.223
# C(year)[T.1992]                   0.9758      0.205      4.751      0.000       0.573       1.378
# C(year)[T.1993]                   1.4998      0.197      7.628      0.000       1.114       1.885
# C(year)[T.1994]                   1.1155      0.202      5.510      0.000       0.719       1.512
# C(year)[T.1995]                   1.4102      0.207      6.812      0.000       1.004       1.816
# C(year)[T.1996]                   1.4169      0.207      6.852      0.000       1.012       1.822
# C(year)[T.1997]                   1.8190      0.214      8.490      0.000       1.399       2.239
# C(year)[T.1998]                   1.7193      0.211      8.159      0.000       1.306       2.132
# C(year)[T.1999]                   1.1759      0.210      5.612      0.000       0.765       1.587
# C(year)[T.2000]                   1.5117      0.204      7.402      0.000       1.111       1.912
# C(year)[T.2001]                   1.3019      0.210      6.188      0.000       0.890       1.714
# C(year)[T.2002]                   1.3160      0.216      6.089      0.000       0.892       1.740
# C(year)[T.2003]                   1.0915      0.207      5.273      0.000       0.686       1.497
# C(year)[T.2004]                   1.2858      0.227      5.662      0.000       0.841       1.731
# C(year)[T.2005]                   1.1492      0.206      5.583      0.000       0.746       1.553
# C(year)[T.2006]                   1.5721      0.228      6.907      0.000       1.126       2.018
# C(year)[T.2007]                   1.3723      0.216      6.350      0.000       0.949       1.796
# C(year)[T.2008]                   1.8544      0.215      8.631      0.000       1.433       2.275
# C(year)[T.2009]                   2.2350      0.206     10.832      0.000       1.831       2.639
# C(year)[T.2010]                   1.9941      0.208      9.607      0.000       1.587       2.401
# C(year)[T.2011]                   1.4397      0.205      7.020      0.000       1.038       1.842
# C(year)[T.2012]                   1.1942      0.209      5.723      0.000       0.785       1.603
# C(year)[T.2013]                   1.2066      0.202      5.982      0.000       0.811       1.602
# C(year)[T.2014]                   1.0479      0.206      5.082      0.000       0.644       1.452
# C(year)[T.2015]                   1.2199      0.201      6.079      0.000       0.827       1.613
# C(year)[T.2016]                   1.4457      0.203      7.139      0.000       1.049       1.843
# C(year)[T.2017]                   1.3056      0.201      6.506      0.000       0.912       1.699
# C(year)[T.2018]                   1.5956      0.204      7.836      0.000       1.196       1.995
# C(year)[T.2019]                   2.2320      0.202     11.076      0.000       1.837       2.627
# C(year)[T.2020]                   2.3309      0.202     11.540      0.000       1.935       2.727
# C(year)[T.2021]                   2.0864      0.198     10.537      0.000       1.698       2.475
# C(year)[T.2022]                   1.4936      0.196      7.615      0.000       1.109       1.878
# C(year)[T.2023]                   1.5689      0.199      7.883      0.000       1.179       1.959
# C(year)[T.2024]                   1.2003      0.200      6.004      0.000       0.808       1.592
# C(year)[T.2025]                   1.2830      0.198      6.482      0.000       0.895       1.671
# C(year)[T.2026]                   1.3990      0.204      6.872      0.000       1.000       1.798
# C(chamber)[T.senate]              0.0089      0.099      0.090      0.928      -0.185       0.203
# =================================================================================================
# /opt/venv/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1649: SpecificationWarning: cov_type not fully supported with freq_weights
#   warnings.warn('cov_type not fully supported with freq_weights',

# %% [markdown]
# ### Sensitivity analysis
#
# Run only on the LCV votes related to "funding and appropriations"

# %%
#filtering votes to only ones analagous with landvote
mech = (con.read_csv('lcv_congressional_votes_mechanism.csv')
    .filter(_.mechanism_category == 'funding_appropriations')
    .select('id')
       )

lcv_df_fundingonly = lcv_df.inner_join(mech,'id')

#computed the annual pro-conservation vote rate among each congressperson
member_year_fundingonly = (lcv_df_fundingonly
    .filter(~_.vote_type.isin(['missing','unknown','excused']))
    .mutate(district_str=_.district.cast("string"))
    .mutate(district_str=_.district_str.fillna("STATEWIDE"))
    .mutate(member_id=_.first_name+'-'+_.last_name+'-'+_.state+'-'+_.chamber+'-'+_.district_str)
    .filter(_.vote_type.isin(['pro','anti','missing']))
    .group_by('year','party','chamber','member_id')
    .agg(total_votes=_.count(),
         total_pro_votes=(_.vote_type=='pro').sum())
    .mutate(pro_rate=_.total_pro_votes/_.total_votes)
    .mutate(party=_.party.substitute({'I':"Independent","R":"Republican","D":"Democrat"}))
    .order_by("total_votes") 
     )


df = member_year_fundingonly.execute().copy()

df = df.dropna(subset=["total_votes", "total_pro_votes", "party", "year", "chamber", "member_id"])
df = df[df["total_votes"] > 0].copy()

df["pro_rate"] = df["total_pro_votes"] / df["total_votes"]

df["party_clean"] = df["party"].astype(str).str.strip().str.upper().replace(
    {"D":"DEMOCRAT", "R":"REPUBLICAN", "I":"INDEPENDENT"}
)
df = df[df["party_clean"].isin(["DEMOCRAT","REPUBLICAN","INDEPENDENT"])].copy()
df["party_clean"] = pd.Categorical(df["party_clean"], categories=["DEMOCRAT","REPUBLICAN","INDEPENDENT"])

# Grouped-binomial GLM (fractional logit)
m = smf.glm(
    "pro_rate ~ C(party_clean) + C(year) + C(chamber)",
    data=df,
    family=sm.families.Binomial(),
    freq_weights=df["total_votes"],   
).fit(
    cov_type="cluster",
    cov_kwds={"groups": df["member_id"]}
)

print(m.summary())
# Out:
# /opt/venv/lib/python3.12/site-packages/ibis/common/deferred.py:414: FutureWarning: `Value.fillna` is deprecated as of v9.1; use fill_null instead
#   return func(*args, **kwargs)
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:               pro_rate   No. Observations:                17110
# Model:                            GLM   Df Residuals:                    36686
# Model Family:                Binomial   Df Model:                           38
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -15377.
# Date:                Wed, 10 Jun 2026   Deviance:                       21220.
# Time:                        23:29:41   Pearson chi2:                 2.17e+04
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.5869
# Covariance Type:              cluster
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                         0.5056      0.152      3.323      0.001       0.207       0.804
# C(party_clean)[T.REPUBLICAN]     -2.8465      0.068    -41.830      0.000      -2.980      -2.713
# C(party_clean)[T.INDEPENDENT]     0.5131      0.374      1.372      0.170      -0.220       1.246
# C(year)[T.1989]                   0.5123      0.256      2.000      0.045       0.010       1.014
# C(year)[T.1990]                  -0.3914      0.179     -2.189      0.029      -0.742      -0.041
# C(year)[T.1993]                   1.0920      0.159      6.868      0.000       0.780       1.404
# C(year)[T.1994]                   1.4233      0.175      8.149      0.000       1.081       1.766
# C(year)[T.1995]                   0.0981      0.179      0.547      0.584      -0.253       0.450
# C(year)[T.1996]                   0.8912      0.176      5.051      0.000       0.545       1.237
# C(year)[T.1997]                   0.8369      0.181      4.615      0.000       0.481       1.192
# C(year)[T.1998]                   2.7713      0.194     14.277      0.000       2.391       3.152
# C(year)[T.1999]                   0.6277      0.170      3.691      0.000       0.294       0.961
# C(year)[T.2000]                   1.0032      0.171      5.861      0.000       0.668       1.339
# C(year)[T.2001]                   0.7382      0.189      3.908      0.000       0.368       1.108
# C(year)[T.2002]                   1.0535      0.191      5.517      0.000       0.679       1.428
# C(year)[T.2003]                   0.8297      0.237      3.502      0.000       0.365       1.294
# C(year)[T.2004]                   0.8449      0.177      4.784      0.000       0.499       1.191
# C(year)[T.2005]                  -0.1257      0.193     -0.652      0.514      -0.504       0.252
# C(year)[T.2006]                   1.4424      0.195      7.378      0.000       1.059       1.826
# C(year)[T.2007]                   0.6138      0.172      3.558      0.000       0.276       0.952
# C(year)[T.2008]                   0.2235      0.204      1.095      0.274      -0.177       0.624
# C(year)[T.2009]                   1.3553      0.168      8.057      0.000       1.026       1.685
# C(year)[T.2010]                   1.5017      0.171      8.756      0.000       1.166       1.838
# C(year)[T.2011]                   1.8390      0.171     10.768      0.000       1.504       2.174
# C(year)[T.2012]                   1.8560      0.167     11.096      0.000       1.528       2.184
# C(year)[T.2013]                   0.7331      0.161      4.544      0.000       0.417       1.049
# C(year)[T.2014]                   0.4463      0.183      2.438      0.015       0.087       0.805
# C(year)[T.2015]                   0.8358      0.172      4.871      0.000       0.500       1.172
# C(year)[T.2016]                   1.6707      0.173      9.670      0.000       1.332       2.009
# C(year)[T.2017]                   0.7911      0.170      4.641      0.000       0.457       1.125
# C(year)[T.2018]                   1.1752      0.166      7.096      0.000       0.851       1.500
# C(year)[T.2019]                   2.0814      0.167     12.462      0.000       1.754       2.409
# C(year)[T.2020]                   2.0374      0.166     12.275      0.000       1.712       2.363
# C(year)[T.2021]                   1.9906      0.165     12.050      0.000       1.667       2.314
# C(year)[T.2022]                   1.0392      0.165      6.308      0.000       0.716       1.362
# C(year)[T.2023]                   1.0860      0.166      6.547      0.000       0.761       1.411
# C(year)[T.2024]                   0.9002      0.171      5.263      0.000       0.565       1.235
# C(year)[T.2026]                   0.7460      0.173      4.313      0.000       0.407       1.085
# C(chamber)[T.senate]              0.3058      0.083      3.686      0.000       0.143       0.468
# =================================================================================================
# /opt/venv/lib/python3.12/site-packages/statsmodels/genmod/generalized_linear_model.py:1649: SpecificationWarning: cov_type not fully supported with freq_weights
#   warnings.warn('cov_type not fully supported with freq_weights',
