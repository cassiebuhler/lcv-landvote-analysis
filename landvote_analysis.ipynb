# %% [markdown]
# # LandVote Analysis
# ## Visualizations + Statistical Tests
#
# For details on data processing, please refer to the code for
# - [<u>LandVote</u>](https://github.com/cassiebuhler/datasets/tree/main/landvote)
# - [<u>Census boundaires</u>](https://github.com/cassiebuhler/datasets/tree/main/census)
# - [<u>Political party</u>](https://github.com/cassiebuhler/datasets/tree/main/political_parties)
#
# In this script, we are visualizing the resulting LandVote data and running statistical tests.

# %%
# %pip install -r requirements.txt
# Out:
# Collecting git+https://github.com/boettiger-lab/cng-python.git (from -r requirements.txt (line 7))
#   Cloning https://github.com/boettiger-lab/cng-python.git to /tmp/pip-req-build-_e_buipz
#   Running command git clone --filter=blob:none --quiet https://github.com/boettiger-lab/cng-python.git /tmp/pip-req-build-_e_buipz
#   Resolved https://github.com/boettiger-lab/cng-python.git to commit 8d93a2c35479e28cf9758c54e45291c6b47de061
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: ibis-framework==12.0.0 in /opt/venv/lib/python3.14/site-packages (from ibis-framework[duckdb]==12.0.0->-r requirements.txt (line 1)) (12.0.0)
# Requirement already satisfied: vl-convert-python==1.9.0.post1 in /opt/venv/lib/python3.14/site-packages (from -r requirements.txt (line 2)) (1.9.0.post1)
# Requirement already satisfied: venny4py==1.0.3 in /opt/venv/lib/python3.14/site-packages (from -r requirements.txt (line 3)) (1.0.3)
# Requirement already satisfied: beautifulsoup4==4.14.3 in /opt/venv/lib/python3.14/site-packages (from -r requirements.txt (line 4)) (4.14.3)
# Requirement already satisfied: lxml==6.1.1 in /opt/venv/lib/python3.14/site-packages (from -r requirements.txt (line 5)) (6.1.1)
# Requirement already satisfied: duckdb<1.5,>=1.4.2 in /opt/venv/lib/python3.14/site-packages (from -r requirements.txt (line 6)) (1.4.5)
# Requirement already satisfied: minio in /opt/venv/lib/python3.14/site-packages (from cng==1.0.10->-r requirements.txt (line 7)) (7.2.20)
# Requirement already satisfied: tippecanoe in /opt/venv/lib/python3.14/site-packages (from cng==1.0.10->-r requirements.txt (line 7)) (2.72.0)
# Requirement already satisfied: atpublic>=2.3 in /opt/venv/lib/python3.14/site-packages (from ibis-framework==12.0.0->ibis-framework[duckdb]==12.0.0->-r requirements.txt (line 1)) (7.0.0)
# Requirement already satisfied: parsy>=2 in /opt/venv/lib/python3.14/site-packages (from ibis-framework==12.0.0->ibis-framework[duckdb]==12.0.0->-r requirements.txt (line 1)) (2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/venv/lib/python3.14/site-packages (from ibis-framework==12.0.0->ibis-framework[duckdb]==12.0.0->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: sqlglot!=26.32.0,>=23.4 in /opt/venv/lib/python3.14/site-packages (from ibis-framework==12.0.0->ibis-framework[duckdb]==12.0.0->-r requirements.txt (line 1)) (30.18.0)
# Requirement already satisfied: toolz>=0.11 in /opt/venv/lib/python3.14/site-packages (from ibis-framework==12.0.0->ibis-framework[duckdb]==12.0.0->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/venv/lib/python3.14/site-packages (from ibis-framework==12.0.0->ibis-framework[duckdb]==12.0.0->-r requirements.txt (line 1)) (4.16.0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/venv/lib/python3.14/site-packages (from ibis-framework==12.0.0->ibis-framework[duckdb]==12.0.0->-r requirements.txt (line 1)) (2026.3)
# Requirement already satisfied: soupsieve>=1.6.1 in /opt/venv/lib/python3.14/site-packages (from beautifulsoup4==4.14.3->-r requirements.txt (line 4)) (2.9.2)
# Requirement already satisfied: numpy<3,>=1.23.2 in /opt/venv/lib/python3.14/site-packages (from ibis-framework[duckdb]==12.0.0->-r requirements.txt (line 1)) (2.5.2)
# Requirement already satisfied: packaging>=21.3 in /opt/venv/lib/python3.14/site-packages (from ibis-framework[duckdb]==12.0.0->-r requirements.txt (line 1)) (26.3)
# Requirement already satisfied: pandas<4,>=1.5.3 in /opt/venv/lib/python3.14/site-packages (from ibis-framework[duckdb]==12.0.0->-r requirements.txt (line 1)) (2.3.3)
# Requirement already satisfied: pyarrow-hotfix>=0.4 in /opt/venv/lib/python3.14/site-packages (from ibis-framework[duckdb]==12.0.0->-r requirements.txt (line 1)) (0.7)
# Requirement already satisfied: pyarrow>=10.0.1 in /opt/venv/lib/python3.14/site-packages (from ibis-framework[duckdb]==12.0.0->-r requirements.txt (line 1)) (25.0.1)
# Requirement already satisfied: rich>=12.4.4 in /opt/venv/lib/python3.14/site-packages (from ibis-framework[duckdb]==12.0.0->-r requirements.txt (line 1)) (15.0.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/venv/lib/python3.14/site-packages (from pandas<4,>=1.5.3->ibis-framework[duckdb]==12.0.0->-r requirements.txt (line 1)) (2026.3.post1)
# Requirement already satisfied: six>=1.5 in /opt/venv/lib/python3.14/site-packages (from python-dateutil>=2.8.2->ibis-framework==12.0.0->ibis-framework[duckdb]==12.0.0->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/venv/lib/python3.14/site-packages (from rich>=12.4.4->ibis-framework[duckdb]==12.0.0->-r requirements.txt (line 1)) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/venv/lib/python3.14/site-packages (from rich>=12.4.4->ibis-framework[duckdb]==12.0.0->-r requirements.txt (line 1)) (2.21.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/venv/lib/python3.14/site-packages (from markdown-it-py>=2.2.0->rich>=12.4.4->ibis-framework[duckdb]==12.0.0->-r requirements.txt (line 1)) (0.1.2)
# Requirement already satisfied: argon2-cffi in /opt/venv/lib/python3.14/site-packages (from minio->cng==1.0.10->-r requirements.txt (line 7)) (25.1.0)
# Requirement already satisfied: certifi in /opt/venv/lib/python3.14/site-packages (from minio->cng==1.0.10->-r requirements.txt (line 7)) (2026.7.22)
# Requirement already satisfied: pycryptodome in /opt/venv/lib/python3.14/site-packages (from minio->cng==1.0.10->-r requirements.txt (line 7)) (3.23.0)
# Requirement already satisfied: urllib3 in /opt/venv/lib/python3.14/site-packages (from minio->cng==1.0.10->-r requirements.txt (line 7)) (2.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/venv/lib/python3.14/site-packages (from argon2-cffi->minio->cng==1.0.10->-r requirements.txt (line 7)) (26.1.0)
# Requirement already satisfied: cffi>=2 in /opt/venv/lib/python3.14/site-packages (from argon2-cffi-bindings->argon2-cffi->minio->cng==1.0.10->-r requirements.txt (line 7)) (2.1.1)
# Requirement already satisfied: pycparser in /opt/venv/lib/python3.14/site-packages (from cffi>=2->argon2-cffi-bindings->argon2-cffi->minio->cng==1.0.10->-r requirements.txt (line 7)) (3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import ibis
from ibis import _
import ibis.expr.datatypes as dt  
import re
from cng.utils import *
from cng.h3 import *
from minio import Minio
import altair as alt
from utils import *
from landvote_fund_categories import fund_cat_map

duckdb_install_h3()
con = ibis.duckdb.connect(extensions = ["spatial"])
set_secrets(con)

# %% [markdown]
# # Load data

# %%
raw_votes= (con.read_parquet('s3://public-tpl-streamlit/nvme/public-tpl/landvote/landvote_party.parquet')
    .drop('geom')
)
# collapse multi-county measures to one row per landvote_id 
votes = get_unique_rows(raw_votes)
votes.to_csv('landvote_data.csv') #saving local copy

# %% [markdown]
# ## add purpose categories

# %%
# categorizing landvote measures based on purpose 

# add fund_categories as a variable 
votes = votes.mutate(
    fund_categories=(
        _.purpose
         .re_split(r'[,;.]|\s+and\s+')           # -> array<string>
         .map(lambda t: t.strip())                # trim each term
         .filter(lambda t: t != '')               # drop empties
         .map(lambda t: t.substitute(fund_cat_map, else_=ibis.null()))
         .filter(lambda c: c.notnull())           # drop unmatched terms
         .unique()                                 # dedupe categories
    )
)

# print summary table of how often each category is used
# note that categories aren't unique, so this will exceed 100%. 
summary = (
    votes
    .filter(_.fund_categories.notnull() & (_.fund_categories.length() > 0))
    .mutate(fund_category=_.fund_categories.unnest())
    .group_by('fund_category')
    .aggregate(n_measures=_.count())
    .mutate(pct=(_.n_measures * 100.0 / votes.filter(_.purpose.notnull()).count()).round(1))
    .order_by(_.n_measures.desc())
)
summary.execute()
# Out:
#             fund_category  n_measures   pct
# 0              Open Space        2592  84.7
# 1      Parks & Recreation        1871  61.2
# 2  Farmland & Agriculture         715  23.4
# 3       Water & Watershed         487  15.9
# 4      Wildlife & Habitat         380  12.4
# 5                 Forests          87   2.8
# 6    Climate & Resilience          21   0.7
# 7                  Equity           4   0.1

# %% [markdown]
# ## Volume asymmetry

# %%
margin_raw= (con.read_parquet('s3://public-tpl-streamlit/nvme/public-tpl/landvote/landvote_party_margin.parquet')
    .drop('geom')
)
# collapse multi-county measures to one row per landvote_id 
margin = get_unique_rows(margin_raw)
print(margin.group_by('jurisdiction','party').agg(total = _.count()).order_by('jurisdiction','party').execute())
# Out:
#         jurisdiction       party  total
# 0             County    Democrat    318
# 1             County  Republican    318
# 2             County        None      1
# 3          Municipal    Democrat   1499
# 4          Municipal       Mixed     71
# 5          Municipal  Republican    646
# 6          Municipal        None      9
# 7   Special District    Democrat     52
# 8   Special District       Mixed     16
# 9   Special District  Republican     46
# 10             State    Democrat     71
# 11             State  Republican     25

# %% [markdown]
# # Charts

# %% [markdown]
# ### Landvote by funding purpose

# %%
filtered = (
    votes
    .filter(_.fund_categories.notnull() & (_.fund_categories.length() > 0))
    .filter(_.party.isin(["Democrat", "Republican"]))
    .mutate(bundle=_.fund_categories.sort().join(" + "))
)
party_totals = filtered.group_by('party').aggregate(party_total=_.count())
bundle_summary = (
    filtered
    .group_by('bundle', 'party')
    .aggregate(n_measures=_.count())
    .join(party_totals, 'party')
    .mutate(pct=(_.n_measures * 100.0 / _.party_total).round(1))
)

df = bundle_summary.execute()
df['bundle'] = df['bundle'].apply(lambda b: f"{b} (only)" if ' + ' not in b else b)

top_bundles = df.groupby('bundle')['pct'].max().nlargest(5).index
df = df[df['bundle'].isin(top_bundles)]
bundle_order = (df[df.party == "Democrat"]
                .sort_values("pct", ascending=False)["bundle"].tolist())

chart = row_bar_chart(
    df,
    category_col="bundle",
    title="Most Common LandVote Funding Categories by Jurisdiction Party",
    category_order=bundle_order,
)
chart.save('landvote_purpose.png', ppi=200)
chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Pass rates by jurisdiction party

# %%
df = (
    votes
    .filter(_.party.isin(["Democrat", "Republican"]))
    .group_by("year", "party")
    .agg(pass_fraction=((_.status.isin(["Pass", "Pass*"]))).cast("int").mean())
    .order_by("year")
    .execute()
)

chart = year_line(
    df,
    y="pass_fraction",
    group="party",
    title="Conservation Measure Pass Rates by Jurisdiction Party (1988–2025)",
    y_title="% Passed",
    stat='percent'
)


chart.save('percent_passed_party.png', ppi=200)
chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Outcome by finance measure

# %%
df = (
    votes
    .mutate(
        other_comment_lc = _.other_comment.fill_null("").lower(),
        fm_lc = _.finance_mechanism.fill_null("").lower(),
    )
    .mutate(
        mechanism_group = ibis.ifelse(
            _.fm_lc.contains("bond"),
            "Bond",
            ibis.ifelse(
                # converting other to tax based on the other_comment column  
                (_.fm_lc.contains("tax")) | ((_.finance_mechanism == "Other") & (_.other_comment_lc.contains("tax"))),
                "Tax",
                "Other",
            ),
        ),
    )
    .filter(_.mechanism_group!="Other")
    .filter(_.party.isin(["Democrat", "Republican"]))
    .group_by("mechanism_group", "party")
    .agg(pass_fraction=(_.status.isin(["Pass", "Pass*"])).cast("int").mean())
    .execute()
)


chart = bar_chart(
    df,
    y="pass_fraction",
    group="party",
    title="Conservation Measure Pass Rates by Jurisdiction Party and Finance Mechanism",
    y_title="% Passed",
    stat='percent'
)


chart.save('party_mechanism.png', ppi=200)
chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Outcome by purpose

# %%
df = (
    votes
    .filter(_.party.isin(["Democrat", "Republican"]))
    .filter(_.fund_categories.length() > 0)
    .mutate(fund_categories=_.fund_categories.unnest())
    .group_by(["party", "fund_categories"])
    .agg(n=_.count())
    .mutate(pct=(_.n * 100.0 / _.n.sum().over(group_by="party")).round(1))
    .pivot_wider(
        names_from="party",
        values_from="pct",
        id_cols=["fund_categories"],
    )
    .order_by(_.Democrat.desc())
    .execute()
)

print(df)
# Out:
#           fund_categories  Republican  Democrat
# 0              Open Space        38.6      44.1
# 1      Parks & Recreation        32.9      28.6
# 2  Farmland & Agriculture        11.6      12.0
# 3       Water & Watershed         8.4       7.5
# 4      Wildlife & Habitat         6.8       5.8
# 5                 Forests         1.5       1.4
# 6    Climate & Resilience         0.1       0.5
# 7                  Equity         0.0       0.1

# %% [markdown]
# ### Volume by party

# %%
print(votes.group_by('party').count().execute())
# Out:
#         party  CountStar()
# 0       Mixed           87
# 1        None           12
# 2    Democrat         1939
# 3  Republican         1034

# %% [markdown]
# ## Equivalence Test - two one-sided t-tests (TOST)
#
# Let $\Delta  = p_D-p_R$ where $\delta$ is a equivalence margin.
#
# $$H_{0}: \Delta \leq - \delta \text{ or } \Delta \geq \delta$$
#
# $$H_{A}: -\delta < \Delta < \delta$$
#
# Short Conclusion:
# Since both p-values $<0.05$ -> reject non-equivalence
# Pass rates are statistically equivalent within $\pm5$ percentage points

# %%
import numpy as np
from statsmodels.stats.proportion import test_proportions_2indep, confint_proportions_2indep

def tost(votes):
    df = votes.execute()  # one row per landvote_id
    df = df[df["party"].isin(["Democrat", "Republican"])].copy()
    df["passed"] = df["status"].isin(["Pass", "Pass*"]).astype(int)
    
    g = df.groupby("party")["passed"].agg(["sum", "count"])
    xD, nD = int(g.loc["Democrat", "sum"]), int(g.loc["Democrat", "count"])
    xR, nR = int(g.loc["Republican", "sum"]), int(g.loc["Republican", "count"])
    
    delta = 0.05   # equivalence margin: ±5 percentage points
    alpha = 0.05
    
    pD = xD / nD
    pR = xR / nR
    diff = pD - pR
    # TOST:
    # 1) H0: (pD - pR) <= -delta  vs  H1: (pD - pR) > -delta
    p_lo = test_proportions_2indep(xD, nD, xR, nR, value=-delta, alternative="larger").pvalue
    
    # 2) H0: (pD - pR) >=  delta  vs  H1: (pD - pR) <  delta
    p_hi = test_proportions_2indep(xD, nD, xR, nR, value= delta, alternative="smaller").pvalue
    
    equivalent = (p_lo < alpha) and (p_hi < alpha)
    
    # CI for difference in proportions
    ci_lo, ci_hi = confint_proportions_2indep(xD, nD, xR, nR, method="score")
    
    print(f"Dem pass rate: {pD:.4f} ({xD}/{nD})")
    print(f"Rep pass rate: {pR:.4f} ({xR}/{nR})")
    print(f"Difference (D-R): {diff:.4f}")
    print(f"95% CI: ({ci_lo:.4f}, {ci_hi:.4f})")
    print(f"TOST p-values: lower={p_lo:.4g}, upper={p_hi:.4g}")
    print(f"Equivalent within ±{delta}? {equivalent}")

# %%
votes = get_unique_rows(raw_votes)
tost(votes)
# Out:
# Dem pass rate: 0.7767 (1506/1939)
# Rep pass rate: 0.7602 (786/1034)
# Difference (D-R): 0.0165
# 95% CI: (-0.0150, 0.0490)
# TOST p-values: lower=2.108e-05, upper=0.02068
# Equivalent within ±0.05? True

# %% [markdown]
# ## Sensitivity analysis
# Assigning Missing Partisan to Republican

# %%
## rerun TOST but reclassify parties 
votes= con.read_parquet('s3://public-tpl-streamlit/nvme/public-tpl/landvote/landvote_party.parquet').drop('geom')
votes = get_unique_rows(votes)


party_val = "Republican" 
votes = votes.mutate(party=_.party.substitute({'Mixed':party_val,"None":party_val,None:party_val}))
tost(votes)
# Out:
# Dem pass rate: 0.7767 (1506/1939)
# Rep pass rate: 0.7652 (867/1133)
# Difference (D-R): 0.0115
# 95% CI: (-0.0190, 0.0427)
# TOST p-values: lower=4.521e-05, upper=0.007431
# Equivalent within ±0.05? True

# %% [markdown]
# Assigning Missing Partisan to Democrat

# %%
## rerun TOST but reclassify parties 
votes= con.read_parquet('s3://public-tpl-streamlit/nvme/public-tpl/landvote/landvote_party.parquet').drop('geom')
votes = get_unique_rows(votes)

party_val = "Democrat" 
votes = votes.mutate(party=_.party.substitute({'Mixed':party_val,"None":party_val,None:party_val}))
tost(votes)
# Out:
# Dem pass rate: 0.7787 (1587/2038)
# Rep pass rate: 0.7602 (786/1034)
# Difference (D-R): 0.0185
# 95% CI: (-0.0126, 0.0507)
# TOST p-values: lower=1.026e-05, upper=0.0266
# Equivalent within ±0.05? True
